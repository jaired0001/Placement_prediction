# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Reading the csv file

# %%
df = pd.read_csv('/content/placement.csv')

# %% [markdown]
# Displaying the data

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
# Steps

# 0. Preprocess + EDA + Feature Selection
# 1. Extract input and output cols
# 2. Scale the values
# 3. Train test split
# 4. Train the model
# 5. Evaluate the model/model selection
# 6. Deploy the model

# %% [markdown]
# Importing mathplotlib diaries

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Plotting the graph for cgpa and iq on x-axis and placement on y-axis

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y.shape
# Out:
# (100,)

# %% [markdown]
# Splittiing the data into training and testing

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 11   6.9  138.0
# 55   7.8  114.0
# 56   6.1   65.0
# 44   7.5   61.0
# 23   4.7   87.0
# ..   ...    ...
# 39   4.6  146.0
# 1    5.9  106.0
# 8    6.1  156.0
# 95   4.3  200.0
# 31   3.9  109.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 11    1
# 55    1
# 56    0
# 44    1
# 23    0
#      ..
# 39    0
# 1     0
# 8     0
# 95    0
# 31    0
# Name: placement, Length: 90, dtype: int64

# %%
X_test
# Out:
#     cgpa     iq
# 49   5.4  135.0
# 63   6.3  128.0
# 92   5.2  110.0
# 9    5.1   66.0
# 36   5.7  140.0
# 37   8.1  149.0
# 13   6.4  116.0
# 45   6.0   66.0
# 33   6.0  149.0
# 83   7.5  130.0

# %% [markdown]
# Implementing standardisation using standard Scalar

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 8.02421518e-01,  3.41267060e-01],
#        [ 1.57988734e+00, -2.47971029e-01],
#        [ 1.11340785e-01, -1.45099879e+00],
#        [ 1.32073207e+00, -1.54920514e+00],
#        [-1.09805050e+00, -9.10863878e-01],
#        [-1.01166541e+00,  4.14921821e-01],
#        [ 8.02421518e-01, -6.89899595e-01],
#        [ 1.11340785e-01, -1.05817340e+00],
#        [ 8.88806609e-01, -2.97074203e-01],
#        [ 8.02421518e-01,  3.65818647e-01],
#        [-1.09805050e+00, -1.77016942e+00],
#        [ 2.18458298e+00, -1.00661507e-01],
#        [-1.01166541e+00,  9.55056735e-01],
#        [ 5.43266243e-01,  3.41267060e-01],
#        [-1.35720577e+00, -2.01568529e+00],
#        [ 1.32073207e+00,  8.32298800e-01],
#        [-7.52510132e-01,  9.57511894e-02],
#        [-8.38895223e-01, -1.50010197e+00],
#        [-1.47814490e-01,  4.39473408e-01],
#        [-1.47814490e-01,  1.02871150e+00],
#        [ 1.14796188e+00,  3.16715473e-01],
#        [-2.34199582e-01,  1.93957537e-01],
# ...

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-0.49335486,  0.2676123 ],
#        [ 0.28411097,  0.09575119],
#        [-0.66612504, -0.34617738],
#        [-0.75251013, -1.42644721],
#        [-0.23419958,  0.39037023],
#        [ 1.83904262,  0.61133452],
#        [ 0.37049606, -0.19886785],
#        [ 0.02495569, -1.42644721],
#        [ 0.02495569,  0.61133452],
#        [ 1.32073207,  0.14485436]])

# %% [markdown]
# Implmemnting logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
# 49    0
# 63    1
# 92    0
# 9     0
# 36    0
# 37    1
# 13    1
# 45    1
# 33    0
# 83    1
# Name: placement, dtype: int64

# %% [markdown]
# Importing Accuracy model

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# Testing the model accuracy

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >
